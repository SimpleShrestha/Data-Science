# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
revenue=[200,250,350]
companies=['google','fb','amazon']
plt.pie(revenue)
plt.plot()
# Out:
# []

# %%
plt.pie(revenue,labels=companies,autopct='%.1f%%',colors=['green','pink','purple'])
plt.plot()
# Out:
# []

# %%
import pandas as pd

# %%
df=pd.read_csv('titanic.csv')

# %%
Survived=(df.Survived==1).sum()
dead=(df.Survived==0).sum()
plt.bar(['Survived','dead'],[Survived,dead])
# Out:
# <BarContainer object of 2 artists>

# %%
plt.pie([Survived,dead],labels=['Survived','dead'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1a61b231990>,
# ...
#  [Text(0.39257483889210154, 1.0275626481479563, 'Survived'),
#   Text(-0.3925747426847421, -1.0275626849034607, 'dead')])

# %%
plt.hist(df.Age,bins=8)
# Out:
# (array([ 64., 115., 230., 155.,  86.,  42.,  17.,   5.]),
#  array([ 0.42  , 10.3675, 20.315 , 30.2625, 40.21  , 50.1575, 60.105 ,
#         70.0525, 80.    ]),
#  <BarContainer object of 8 artists>)

# %%
plt.pie(revenue,labels=companies,autopct='%.f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
